# %% [markdown]
# <a href="https://colab.research.google.com/github/mark1702/HashTation/blob/main/hashtags_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence_transformers datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
# !git clone https://github.com/hoa92ng/HashTation.git
# Out:
# Cloning into 'HashTation'...
# remote: Enumerating objects: 210, done.
# remote: Counting objects: 100% (210/210), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 210 (delta 94), reused 140 (delta 29), pack-reused 0
# Receiving objects: 100% (210/210), 14.48 MiB | 16.93 MiB/s, done.
# Resolving deltas: 100% (94/94), done.

# %%
cd HashTation
# Out:
# /content/HashTation

# %%
https://drive.google.com/file/d/1-QtxxXcXiR8tpl-2mlJC2n51NtIPmug_/view?usp=drive_link
# !gdown 1-QtxxXcXiR8tpl-2mlJC2n51NtIPmug_
#/content/HashTation/generated_model_emoji.ml

# %%
# !python dataloaders/dataloaders_classification.py
# Out:
# /content/HashTation/dataloaders/dataloaders_classification.py:116: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if is_train and (is_pilot is not "none"):
# data/tweeteval-processed-full/emotion/test.csv
# data/tweeteval-processed-full/emotion/train.csv
# data/tweeteval-processed-full/emotion/val.csv
# data/tweeteval-processed-full/irony/test.csv
# data/tweeteval-processed-full/irony/train.csv
# data/tweeteval-processed-full/irony/val.csv
# data/tweeteval-processed-full/stance/test.csv
# data/tweeteval-processed-full/stance/train.csv
# data/tweeteval-processed-full/stance/val.csv
# data/tweeteval-processed-full/emoji/test.csv
# data/tweeteval-processed-full/emoji/train.csv
# data/tweeteval-processed-full/emoji/val.csv
# data/tweeteval-processed-full/hate/test.csv
# data/tweeteval-processed-full/hate/train.csv
# data/tweeteval-processed-full/hate/val.csv
# data/tweeteval-processed-full/offensive/test.csv
# data/tweeteval-processed-full/offensive/train.csv
# ...

# %%
# !python hashtag_generation.py --dataset emoji --n_epochs 5 --save_path /content/drive/MyDrive/projects/hashtags/generated_model.ml
# Out:
# args: Namespace(dataset='emoji', model='bart-base', batch_size=64, n_epochs=5, lr=1e-05, logging=False, save_path='/content/drive/MyDrive/projects/hashtags/generated_model.ml', beam_size=5, decoder_early_stopping=True, length_penalty=0.6, decoder_min_length=1, no_repeat_ngram_size=3, tam_module=True)
# Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Use pytorch device_name: cuda
# Batches: 100% 657/657 [00:06<00:00, 99.30it/s]
#   0% 0/328 [00:00<?, ?it/s]
# Batches: 100% 2/2 [00:00<00:00, 110.12it/s]
#   0% 1/328 [00:01<07:37,  1.40s/it]
# Batches: 100% 2/2 [00:00<00:00, 70.84it/s]
#   1% 2/328 [00:02<07:24,  1.36s/it]
# Batches: 100% 2/2 [00:00<00:00, 71.97it/s]
#   1% 3/328 [00:04<07:17,  1.35s/it]
# Batches: 100% 2/2 [00:00<00:00, 107.75it/s]
#   1% 4/328 [00:05<07:10,  1.33s/it]
# Batches: 100% 2/2 [00:00<00:00, 95.79it/s]
#   2% 5/328 [00:06<07:04,  1.31s/it]
# Batches: 100% 2/2 [00:00<00:00, 108.22it/s]
#   2% 6/328 [00:07<06:59,  1.30s/it]
# ...

# %%
# !python hashtag_generation_inference.py --dataset emoji --model_path /content/drive/MyDrive/projects/hashtags/generated_model_emoji.ml --data_path /content/HashTation/data/tweeteval-processed-gen_no_hastags/tweeteval-processed-full --save_path /content/HashTation/data/tweeteval-processed-gen_no_hastags/hashtags_prediction
# Out:
# Streaming output truncated to the last 5000 lines.
#  91% 25442/27941 [42:14<04:47,  8.68it/s]
# Batches: 100% 1/1 [00:00<00:00, 147.83it/s]
#  91% 25443/27941 [42:14<04:42,  8.84it/s]
# Batches: 100% 1/1 [00:00<00:00, 144.88it/s]
#
# Batches: 100% 1/1 [00:00<00:00, 136.54it/s]
#  91% 25445/27941 [42:15<04:32,  9.16it/s]
# Batches: 100% 1/1 [00:00<00:00, 88.89it/s]
#
# Batches: 100% 1/1 [00:00<00:00, 115.16it/s]
#  91% 25447/27941 [42:15<04:20,  9.59it/s]
# Batches: 100% 1/1 [00:00<00:00, 124.98it/s]
#
# Batches: 100% 1/1 [00:00<00:00, 95.92it/s]
#  91% 25449/27941 [42:15<04:25,  9.38it/s]
# Batches: 100% 1/1 [00:00<00:00, 94.58it/s]
#  91% 25450/27941 [42:15<04:34,  9.07it/s]
# Batches: 100% 1/1 [00:00<00:00, 115.43it/s]
#  91% 25451/27941 [42:15<04:49,  8.61it/s]
# Batches: 100% 1/1 [00:00<00:00, 90.95it/s]
#  91% 25452/27941 [42:15<05:14,  7.92it/s]
# Batches: 100% 1/1 [00:00<00:00, 166.82it/s]
#  91% 25453/27941 [42:16<04:58,  8.34it/s]
# ...

# %%
# Out:
# [main bd8df79] Bug Fix
#  9 files changed, 24 insertions(+), 7 deletions(-)
# Enumerating objects: 25, done.
# Counting objects: 100% (25/25), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 10.62 KiB | 3.54 MiB/s, done.
# Total 16 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/hoa92ng/HashTation.git
#    cf2dc4f..bd8df79  main -> main

# %%
# !python dataloaders/dataloaders_classification.py
# Out:
# /content/HashTation/dataloaders/dataloaders_classification.py:177: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if is_train and (is_pilot is not "none"):
# /content/HashTation/data/tweeteval-processed-full/emoji/test.csv /content/HashTation/data/tweeteval-processed-gen_no_hastags/hashtags_prediction/emoji_tam/test.csv
# Done and save file to /content/HashTation/data/tweeteval-processed-gen/tweeteval-processed-full_added_hashtag/emoji/test.csv
# /content/HashTation/data/tweeteval-processed-full/emoji/train.csv /content/HashTation/data/tweeteval-processed-gen_no_hastags/hashtags_prediction/emoji_tam/train.csv
# Done and save file to /content/HashTation/data/tweeteval-processed-gen/tweeteval-processed-full_added_hashtag/emoji/train.csv
# /content/HashTation/data/tweeteval-processed-full/emoji/val.csv /content/HashTation/data/tweeteval-processed-gen_no_hastags/hashtags_prediction/emoji_tam/val.csv
# ...

# %%
# 1% du lieu. co hashtag
# !python classification.py --dataset emoji --save_path /content/drive/MyDrive/projects/hashtags/classification_model_emoji.ml
# Out:
# args: Namespace(dataset='emoji', model='timelms', fusion_type='none', tam_module=False, frozen=False, low_resource=True, pilot='none', save_path='/content/drive/MyDrive/projects/hashtags/classification_model_emoji.ml', batch_size=64, n_epochs=10, lr=5e-05, logging=False, out_file=None)
# 445
# 4930
# 49664
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-mar2022 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100% 6/6 [00:07<00:00,  1.33s/it]
# Train epoch 0: Loss=2.9875622193018594 | Acc=0.1328125
# 100% 77/77 [00:30<00:00,  2.57it/s]
# ...

# %%
# 1% du lieu. khong co hashtag
# !python classification.py --dataset emoji --save_path /content/drive/MyDrive/projects/hashtags/classification_model_emoji_temp.ml
# Out:
# args: Namespace(dataset='emoji', model='timelms', fusion_type='none', tam_module=False, frozen=False, low_resource=True, pilot='none', save_path='/content/drive/MyDrive/projects/hashtags/classification_model_emoji_temp.ml', batch_size=64, n_epochs=10, lr=5e-05, logging=False, out_file=None)
# 445
# 4930
# 49664
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-mar2022 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100% 6/6 [00:07<00:00,  1.24s/it]
# Train epoch 0: Loss=2.9017080863316855 | Acc=0.1484375
# 100% 77/77 [00:30<00:00,  2.56it/s]
# ...

# %%
# 100% du lieu. co hashtag
# !python classification.py --dataset emoji --save_path /content/drive/MyDrive/projects/hashtags/classification_model_emoji.ml
# Out:
# args: Namespace(dataset='emoji', model='timelms', fusion_type='none', tam_module=False, frozen=False, low_resource=False, pilot='none', save_path='/content/drive/MyDrive/projects/hashtags/classification_model_emoji.ml', batch_size=64, n_epochs=10, lr=5e-05, logging=False, out_file=None)
# 44489
# 4930
# 49664
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-mar2022 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100% 695/695 [13:53<00:00,  1.20s/it]
# Train epoch 0: Loss=1.9402557330165835 | Acc=0.41486061151079134
# 100% 77/77 [00:30<00:00,  2.49it/s]
# ...
